# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import gensim

# %%
# %%time
wv = Word2Vec.load("w2v_300.model")
# Out:
# CPU times: user 439 ms, sys: 71.9 ms, total: 511 ms
# Wall time: 510 ms

# %%
variance = []
X = wv.wv.vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('w2v, 300, train+test')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()

# %%
# %%time
wv = Word2Vec.load("w2v_300.model")
# Out:
# CPU times: user 279 ms, sys: 157 ms, total: 436 ms
# Wall time: 2.98 s

# %%
plt.rcParams.update({'font.size': 13})

# %%
variance = []
X = wv.wv.vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 5))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='0.99')
plt.axvline(x=80, color='k', linestyle='--')
plt.axvline(x=115, color='k', linestyle='--')
plt.axvline(x=300, color='k', linestyle='--')

plt.xticks([0, 80, 115, 300])
plt.yticks([0.8, 0.85, 0.9, 0.95, 0.99, 1.0])
plt.title('PCA analyse for w2v components from train set')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.ylim(0.8,1.02)
plt.grid()
# plt.legend(loc=4)

plt.show()

# %%
variance = []
X = wv.wv.vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('w2v, 300, train')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)
plt.xlim(90,120)

plt.show()

# %%
# %%time
wv = gensim.models.KeyedVectors.load_word2vec_format(
    "GoogleNews-vectors-negative300.bin.gz", binary=True, limit=1000000)
# Out:
# CPU times: user 30.1 s, sys: 1.48 s, total: 31.6 s
# Wall time: 34.6 s

# %%
variance = []
X = wv.wv.vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('w2v, 300, GoogleNews-vectors')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()
# Out:
# /home/amirhossein/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
train_x_vectors = np.load("tfidf_train_x_300.npy")

# %%
variance = []
X = train_x_vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('TF-IDF, 300, train')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()

# %%
test_x_vectors = np.load("tfidf_test_x_300.npy")

# %%
variance = []
X = train_x_vectors
pca = PCA(n_components=300)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('TF-IDF, 300, test')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()

# %%
train_x_vectors = np.load("tfidf_train_x_1000.npy")

# %%
variance = []
X = train_x_vectors
pca = PCA(n_components=1000)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('TF-IDF, 1000, train')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()

# %%
test_x_vectors = np.load("tfidf_test_x_1000.npy")

# %%
variance = []
X = test_x_vectors
pca = PCA(n_components=1000)
pca.fit(X)
variance = pca.explained_variance_ratio_
plt.figure(figsize=(10, 10))

accumulated_variance = [0]

for var in variance:
    accumulated_variance.append(accumulated_variance[-1] + var)
accumulated_variance.remove(0)

plt.bar(np.arange(len(accumulated_variance)), accumulated_variance, label='Accumulated Variance')
plt.axhline(y=0.99, color='r', linestyle='--', label='99%')

plt.title('TF-IDF, 1000, test')
plt.xlabel('Component Number')
plt.ylabel('Accumulated Variance')
plt.grid()
plt.legend(loc=4)

plt.show()
